# %% [markdown]
# <a href="https://www.kaggle.com/code/mdramjanali/mns-based-thin-films-deposition?scriptVersionId=351079654" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# getting libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import kagglehub
import os

# %%
# transferring and unzipping into working dir
# !kaggle datasets download -d mdramjanali/mns-ndataset-zip
# !unzip -q mns-ndataset-zip.zip -d /kaggle/working/
# !rm mns-ndataset-zip.zip
# Out:
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2)
# Dataset URL: https://www.kaggle.com/datasets/mdramjanali/mns-ndataset-zip
# License(s): unknown
# Downloading mns-ndataset-zip.zip to /kaggle/working
# 100%|█████████████████████████████████████████| 788M/788M [00:06<00:00, 131MB/s]

# %%
target_dir = '/kaggle/working/MnS manuscript dataset'

for item in os.listdir(target_dir):
    if os.path.isdir(os.path.join(target_dir, item)):
        print(item)
# Out:
# SEM
# EDS
# photocatalysis kinetics meassurement
# XRD
# FTIR
# AFM-scans
# XPS

# %%
import os

eds_path = '/kaggle/working/MnS manuscript dataset/EDS'
print(os.listdir(eds_path))
# Out:
# ['EDS.csv', 'MnS 1-2.5 1M dissolution time test.csv']

# %%
import os

for file in os.listdir('/kaggle/working/MnS manuscript dataset/XRD'):
    print(file)
# Out:
# MnS -2-PA-05M-1-2,5-GIXRD omega05deg.xy
# MnS -1-GIXRD omega05deg.xy
# MnS -6-PA+AN-1M-1-1-GIXRD omega05deg.xy
# MnS -4-PA+MeOH-1M-1-1-GIXRD omega05deg.xy
# MnS -6-PA+AN-1M-1-1-GIXRD omega05deg-V2.xy
# MnS -5-PA+MeOH-05M-1-2,5-GIXRD omega05deg.xy
# MnS -3-PA-1M-1-5-GIXRD omega05deg.xy

# %%
import os

eds_path = '/kaggle/working/MnS manuscript dataset/EDS'
print(os.listdir(eds_path))
# Out:
# ['EDS.csv', 'MnS 1-2.5 1M dissolution time test.csv']

# %%
# dir, subdirs
import os
for dirname, subdirs, _ in os.walk('/kaggle/working/MnS manuscript dataset'):
    for subdir in subdirs:
        print(os.path.join(dirname, subdir))
# Out:
# /kaggle/working/MnS manuscript dataset/SEM
# /kaggle/working/MnS manuscript dataset/EDS
# /kaggle/working/MnS manuscript dataset/photocatalysis kinetics meassurement
# /kaggle/working/MnS manuscript dataset/XRD
# /kaggle/working/MnS manuscript dataset/FTIR
# /kaggle/working/MnS manuscript dataset/AFM-scans
# /kaggle/working/MnS manuscript dataset/XPS
# /kaggle/working/MnS manuscript dataset/SEM/6 MnS PA-AN 1_5 1M
# /kaggle/working/MnS manuscript dataset/SEM/2 MnS PA-MeOH 1_1 1M
# /kaggle/working/MnS manuscript dataset/SEM/1 MnS PA 1_1 1M
# /kaggle/working/MnS manuscript dataset/SEM/disolution time dependence MnS PA 1-2.5 1M
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations
# /kaggle/working/MnS manuscript dataset/SEM/4 MnS PA 1_5 1M
# /kaggle/working/MnS manuscript dataset/SEM/5 MnS PA-MeOH 1_5 1M
# /kaggle/working/MnS manuscript dataset/SEM/3 MnS PA-AN 1_1 1M
# /kaggle/working/MnS manuscript dataset/SEM/6 MnS PA-AN 1_5 1M/T150
# /kaggle/working/MnS manuscript dataset/SEM/6 MnS PA-AN 1_5 1M/T300
# /kaggle/working/MnS manuscript dataset/SEM/6 MnS PA-AN 1_5 1M/T60
# /kaggle/working/MnS manuscript dataset/SEM/2 MnS PA-MeOH 1_1 1M/T150
# /kaggle/working/MnS manuscript dataset/SEM/2 MnS PA-MeOH 1_1 1M/T300
# /kaggle/working/MnS manuscript dataset/SEM/2 MnS PA-MeOH 1_1 1M/T60
# /kaggle/working/MnS manuscript dataset/SEM/1 MnS PA 1_1 1M/T150
# /kaggle/working/MnS manuscript dataset/SEM/1 MnS PA 1_1 1M/T300
# /kaggle/working/MnS manuscript dataset/SEM/1 MnS PA 1_1 1M/T60
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA 1_2.5 c=0,5M T300
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA 1_5 c=0,1M T300
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA-AN 1_2.5 c=0,5M T300
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA-AN 1_1 c=0,5m T300
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA-MeOH 1_2.5 c=0,5M T300
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA-MeOH 1_1 c=0,5M T300
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA 1_2,5 c=0,3M
# /kaggle/working/MnS manuscript dataset/SEM/4 MnS PA 1_5 1M/T150
# /kaggle/working/MnS manuscript dataset/SEM/4 MnS PA 1_5 1M/T300
# /kaggle/working/MnS manuscript dataset/SEM/4 MnS PA 1_5 1M/T60
# /kaggle/working/MnS manuscript dataset/SEM/5 MnS PA-MeOH 1_5 1M/T150
# /kaggle/working/MnS manuscript dataset/SEM/5 MnS PA-MeOH 1_5 1M/T300
# /kaggle/working/MnS manuscript dataset/SEM/5 MnS PA-MeOH 1_5 1M/T60
# /kaggle/working/MnS manuscript dataset/SEM/3 MnS PA-AN 1_1 1M/T150
# /kaggle/working/MnS manuscript dataset/SEM/3 MnS PA-AN 1_1 1M/T300
# /kaggle/working/MnS manuscript dataset/SEM/3 MnS PA-AN 1_1 1M/T60
# /kaggle/working/MnS manuscript dataset/FTIR/precipitates from solution
# /kaggle/working/MnS manuscript dataset/FTIR/films
# /kaggle/working/MnS manuscript dataset/XPS/2 - MnS PA - MeOH 1_1
# /kaggle/working/MnS manuscript dataset/XPS/1 - MnS PA 1_1
# /kaggle/working/MnS manuscript dataset/XPS/4 - MnS PA 1_5
# /kaggle/working/MnS manuscript dataset/XPS/3 - MnS PA - AN 1_1
# /kaggle/working/MnS manuscript dataset/XPS/6 - MnS PA - AN 1_5
# /kaggle/working/MnS manuscript dataset/XPS/5 - MnS PA - MeOH 1_5

# %%
import os

for root, dirs, files in os.walk('/kaggle/working'):
    for d in dirs:
        print(os.path.join(root, d))
# Out:
# /kaggle/working/MnS manuscript dataset
# /kaggle/working/MnS manuscript dataset/SEM
# /kaggle/working/MnS manuscript dataset/EDS
# /kaggle/working/MnS manuscript dataset/photocatalysis kinetics meassurement
# /kaggle/working/MnS manuscript dataset/XRD
# /kaggle/working/MnS manuscript dataset/FTIR
# /kaggle/working/MnS manuscript dataset/AFM-scans
# /kaggle/working/MnS manuscript dataset/XPS
# /kaggle/working/MnS manuscript dataset/SEM/6 MnS PA-AN 1_5 1M
# /kaggle/working/MnS manuscript dataset/SEM/2 MnS PA-MeOH 1_1 1M
# /kaggle/working/MnS manuscript dataset/SEM/1 MnS PA 1_1 1M
# /kaggle/working/MnS manuscript dataset/SEM/disolution time dependence MnS PA 1-2.5 1M
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations
# /kaggle/working/MnS manuscript dataset/SEM/4 MnS PA 1_5 1M
# /kaggle/working/MnS manuscript dataset/SEM/5 MnS PA-MeOH 1_5 1M
# /kaggle/working/MnS manuscript dataset/SEM/3 MnS PA-AN 1_1 1M
# /kaggle/working/MnS manuscript dataset/SEM/6 MnS PA-AN 1_5 1M/T150
# /kaggle/working/MnS manuscript dataset/SEM/6 MnS PA-AN 1_5 1M/T300
# /kaggle/working/MnS manuscript dataset/SEM/6 MnS PA-AN 1_5 1M/T60
# /kaggle/working/MnS manuscript dataset/SEM/2 MnS PA-MeOH 1_1 1M/T150
# /kaggle/working/MnS manuscript dataset/SEM/2 MnS PA-MeOH 1_1 1M/T300
# /kaggle/working/MnS manuscript dataset/SEM/2 MnS PA-MeOH 1_1 1M/T60
# /kaggle/working/MnS manuscript dataset/SEM/1 MnS PA 1_1 1M/T150
# /kaggle/working/MnS manuscript dataset/SEM/1 MnS PA 1_1 1M/T300
# /kaggle/working/MnS manuscript dataset/SEM/1 MnS PA 1_1 1M/T60
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA 1_2.5 c=0,5M T300
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA 1_5 c=0,1M T300
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA-AN 1_2.5 c=0,5M T300
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA-AN 1_1 c=0,5m T300
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA-MeOH 1_2.5 c=0,5M T300
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA-MeOH 1_1 c=0,5M T300
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA 1_2,5 c=0,3M
# /kaggle/working/MnS manuscript dataset/SEM/4 MnS PA 1_5 1M/T150
# /kaggle/working/MnS manuscript dataset/SEM/4 MnS PA 1_5 1M/T300
# /kaggle/working/MnS manuscript dataset/SEM/4 MnS PA 1_5 1M/T60
# /kaggle/working/MnS manuscript dataset/SEM/5 MnS PA-MeOH 1_5 1M/T150
# /kaggle/working/MnS manuscript dataset/SEM/5 MnS PA-MeOH 1_5 1M/T300
# /kaggle/working/MnS manuscript dataset/SEM/5 MnS PA-MeOH 1_5 1M/T60
# /kaggle/working/MnS manuscript dataset/SEM/3 MnS PA-AN 1_1 1M/T150
# /kaggle/working/MnS manuscript dataset/SEM/3 MnS PA-AN 1_1 1M/T300
# /kaggle/working/MnS manuscript dataset/SEM/3 MnS PA-AN 1_1 1M/T60
# /kaggle/working/MnS manuscript dataset/FTIR/precipitates from solution
# /kaggle/working/MnS manuscript dataset/FTIR/films
# /kaggle/working/MnS manuscript dataset/XPS/2 - MnS PA - MeOH 1_1
# /kaggle/working/MnS manuscript dataset/XPS/1 - MnS PA 1_1
# /kaggle/working/MnS manuscript dataset/XPS/4 - MnS PA 1_5
# /kaggle/working/MnS manuscript dataset/XPS/3 - MnS PA - AN 1_1
# /kaggle/working/MnS manuscript dataset/XPS/6 - MnS PA - AN 1_5
# /kaggle/working/MnS manuscript dataset/XPS/5 - MnS PA - MeOH 1_5

# %%
# dir, files
import os
for dirname, _, filenames in os.walk('/kaggle/working'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/working/__notebook__.ipynb
# /kaggle/working/MnS manuscript dataset/SEM/6 MnS PA-AN 1_5 1M/T150/MnS 1-5 1M T150 20um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/6 MnS PA-AN 1_5 1M/T150/MnS 1-5 1M T150 200um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/6 MnS PA-AN 1_5 1M/T150/MnS 1-5 1M T150 2.5um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/6 MnS PA-AN 1_5 1M/T150/MnS 1-5 1M T150 200um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/6 MnS PA-AN 1_5 1M/T150/MnS 1-5 1M T150 5um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/6 MnS PA-AN 1_5 1M/T150/MnS 1-5 1M T150 5um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/6 MnS PA-AN 1_5 1M/T150/MnS 1-5 1M T150 20um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/6 MnS PA-AN 1_5 1M/T150/MnS 1-5 1M T150 2.5um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/6 MnS PA-AN 1_5 1M/T300/9. MnS PA-AN 1-5 1M 2.5um.tif
# /kaggle/working/MnS manuscript dataset/SEM/6 MnS PA-AN 1_5 1M/T300/9. MnS PA-AN 1-5 1M 200um.tif
# /kaggle/working/MnS manuscript dataset/SEM/6 MnS PA-AN 1_5 1M/T300/9. MnS PA-AN 1-5 1M 20um.tif
# /kaggle/working/MnS manuscript dataset/SEM/6 MnS PA-AN 1_5 1M/T300/9. MnS PA-AN 1-5 1M 5um.tif
# /kaggle/working/MnS manuscript dataset/SEM/6 MnS PA-AN 1_5 1M/T60/MnS 1-5 1M T60 20um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/6 MnS PA-AN 1_5 1M/T60/MnS 1-5 1M T60 2.5um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/6 MnS PA-AN 1_5 1M/T60/MnS 1-5 1M T60 200um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/6 MnS PA-AN 1_5 1M/T60/MnS 1-5 1M T60 200um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/6 MnS PA-AN 1_5 1M/T60/MnS 1-5 1M T60 5um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/6 MnS PA-AN 1_5 1M/T60/MnS 1-5 1M T60 20um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/6 MnS PA-AN 1_5 1M/T60/MnS 1-5 1M T60 5um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/6 MnS PA-AN 1_5 1M/T60/MnS 1-5 1M T60 2.5um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/2 MnS PA-MeOH 1_1 1M/T150/MnS 1-1 1M T150 20um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/2 MnS PA-MeOH 1_1 1M/T150/MnS 1-1 1M T150 5um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/2 MnS PA-MeOH 1_1 1M/T150/MnS 1-1 1M T150 5um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/2 MnS PA-MeOH 1_1 1M/T150/MnS 1-1 1M T150 20um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/2 MnS PA-MeOH 1_1 1M/T150/MnS 1-1 1M T150 2.5um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/2 MnS PA-MeOH 1_1 1M/T150/MnS 1-1 1M T150 2.5um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/2 MnS PA-MeOH 1_1 1M/T300/5. MnS PA-MOH 1-1 1M 5um.tif
# /kaggle/working/MnS manuscript dataset/SEM/2 MnS PA-MeOH 1_1 1M/T300/5. MnS PA-MOH 1-1 1M 200um.tif
# /kaggle/working/MnS manuscript dataset/SEM/2 MnS PA-MeOH 1_1 1M/
20um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/disolution time dependence MnS PA 1-2.5 1M/1. MnS 1-2.5 1M PA 7 daysT60 2.5um v1 (13).tif
# /kaggle/working/MnS manuscript dataset/SEM/disolution time dependence MnS PA 1-2.5 1M/4. MnS 1-2.5 1M 5days T150 2.5um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/disolution time dependence MnS PA 1-2.5 1M/1. MnS 1-2.5 1M PA 7 daysT60 2.5um v1 (10).tif
# /kaggle/working/MnS manuscript dataset/SEM/disolution time dependence MnS PA 1-2.5 1M/1. MnS 1-2.5 1M PA 7 daysT60 2.5um v1 (8).tif
# /kaggle/working/MnS manuscript dataset/SEM/disolution time dependence MnS PA 1-2.5 1M/6. MnS 1-2.5 1M 9daysT150 200um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/disolution time dependence MnS PA 1-2.5 1M/2. MnS 1-2.5 1M 3days T150 200um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/disolution time dependence MnS PA 1-2.5 1M/1. MnS 1-2.5 1M PA 7 daysT60 2.5um v1 (9).tif
# /kaggle/working/MnS manuscript dataset/SEM/disolution time dependence MnS PA 1-2.5 1M/5. MnS 1-2.5 1M 9daysT60 200um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/disolution time dependence MnS PA 1-2.5 1M/2. MnS 1-2.5 1M 3days T150 5um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/disolution time dependence MnS PA 1-2.5 1M/2. MnS 1-2.5 1M 3days T150 200um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/disolution time dependence MnS PA 1-2.5 1M/2. MnS 1-2.5 1M 3days T150 20um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/disolution time dependence MnS PA 1-2.5 1M/3. MnS 1-2.5 1M 5days T60 2.5um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA 1_2.5 c=0,5M T300/10. MnS PA 1-2.5 0.5M 2.5um.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA 1_2.5 c=0,5M T300/10. MnS PA 1-2.5 0.5M 20um.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA 1_2.5 c=0,5M T300/10. MnS PA 1-2.5 0.5M 200um.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA 1_2.5 c=0,5M T300/10. MnS PA 1-2.5 0.5M 5um.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA 1_5 c=0,1M T300/2. MnS PA 1-5 0.1M 5um.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA 1_5 c=0,1M T300/2. MnS PA 1-5 0.1M 20um.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA 1_5 c=0,1M T300/2. MnS PA 1-5 0.1M 200um.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA 1_5 c=0,1M T300/2. MnS PA 1-5 0.1M 2.5um.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA-AN 1_2.5 c=0,5M T300/12. MnS PA-AN 1-2.5 0.5M 2.5um.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA-AN 1_2.5 c=0,5M T300/12. MnS PA-AN 1-2.5 0.5M 5um.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA-AN 1_2.5 c=0,5M T300/12. MnS PA-AN 1-2.5 0.5M 20um.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA-AN 1_2.5 c=0,5M T300/12. MnS PA-AN 1-2.5 0.5M 200um.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA-AN 1_1 c=0,5m T300/7. MnS PA-AN 1-1 0.5M 200um.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA-AN 1_1 c=0,5m T300/7. MnS PA-AN 1-1 0.5M 2.5um.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA-AN 1_1 c=0,5m T300/7. MnS PA-AN 1-1 0.5M 20um.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA-AN 1_1 c=0,5m T300/7. MnS PA-AN 1-1 0.5M 5um.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA-MeOH 1_2.5 c=0,5M T300/11. MnS PA-MOH 1-2.5 0.5M 2.5um.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA-MeOH 1_2.5 c=0,5M T300/11. MnS PA-MOH 1-2.5 0.5M 200um.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA-MeOH 1_2.5 c=0,5M T300/11. MnS PA-MOH 1-2.5 0.5M 5um.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA-MeOH 1_2.5 c=0,5M T300/11. MnS PA-MOH 1-2.5 0.5M 20um.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA-MeOH 1_1 c=0,5M T300/4. MnS PA-MOH 1-1 0.5M 200um.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA-MeOH 1_1 c=0,5M T300/4. MnS PA-MOH 1-1 0.5M 20um.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA-MeOH 1_1 c=0,5M T300/4. MnS PA-MOH 1-1 0.5M 2.5um.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA-MeOH 1_1 c=0,5M T300/4. MnS PA-MOH 1-1 0.5M 5um.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA 1_2,5 c=0,3M/MnS PA T150 200um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA 1_2,5 c=0,3M/MnS PA T60 2.5um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA 1_2,5 c=0,3M/MnS PA T60 2.5um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA 1_2,5 c=0,3M/MnS PA T60 5um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA 1_2,5 c=0,3M/MnS PA T150 2.5um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA 1_2,5 c=0,3M/MnS PA T150 5um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA 1_2,5 c=0,3M/MnS PA T150 5um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA 1_2,5 c=0,3M/MnS PA T150 2.5um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA 1_2,5 c=0,3M/MnS PA T150 20um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA 1_2,5 c=0,3M/MnS PA T60 200um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA 1_2,5 c=0,3M/MnS PA T60 20um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA 1_2,5 c=0,3M/MnS PA T60 20um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA 1_2,5 c=0,3M/MnS PA T150 20um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA 1_2,5 c=0,3M/MnS PA T60 5um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA 1_2,5 c=0,3M/MnS PA T60 200um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/lower concentrations/MnS PA 1_2,5 c=0,3M/MnS PA T150 200um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/4 MnS PA 1_5 1M/T150/MnS 1-5 1M T150 20um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/4 MnS PA 1_5 1M/T150/MnS 1-5 1M T150 2.5um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/4 MnS PA 1_5 1M/T150/MnS 1-5 1M T150 5um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/4 MnS PA 1_5 1M/T150/MnS 1-5 1M T150 5um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/4 MnS PA 1_5 1M/T150/MnS 1-5 1M T150 20um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/4 MnS PA 1_5 1M/T150/MnS 1-5 1M T150 2.5um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/4 MnS PA 1_5 1M/T300/3. MnS PA 1-5 1M 200um.tif
# /kaggle/working/MnS manuscript dataset/SEM/4 MnS PA 1_5 1M/T300/3. MnS PA 1-5 1M 5um.tif
# /kaggle/working/MnS manuscript dataset/SEM/4 MnS PA 1_5 1M/T300/3. MnS PA 1-5 1M 2.5um.tif
# /kaggle/working/MnS manuscript dataset/SEM/4 MnS PA 1_5 1M/T300/3. MnS PA 1-5 1M 20um.tif
# /kaggle/working/MnS manuscript dataset/SEM/4 MnS PA 1_5 1M/T60/MnS 1-5 1M T60 20um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/4 MnS PA 1_5 1M/T60/MnS 1-5 1M T60 2.5um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/4 MnS PA 1_5 1M/T60/MnS 1-5 1M T60 5um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/4 MnS PA 1_5 1M/T60/MnS 1-5 1M T60 20um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/4 MnS PA 1_5 1M/T60/MnS 1-5 1M T60 5um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/4 MnS PA 1_5 1M/T60/MnS 1-5 1M T60 2.5um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/5 MnS PA-MeOH 1_5 1M/T150/MnS 1-5 1M T150 20um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/5 MnS PA-MeOH 1_5 1M/T150/MnS 1-5 1M T150 200um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/5 MnS PA-MeOH 1_5 1M/T150/MnS 1-5 1M T150 2.5um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/5 MnS PA-MeOH 1_5 1M/T150/MnS 1-5 1M T150 200um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/5 MnS PA-MeOH 1_5 1M/T150/MnS 1-5 1M T150 5um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/5 MnS PA-MeOH 1_5 1M/T150/MnS 1-5 1M T150 5um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/5 MnS PA-MeOH 1_5 1M/T150/MnS 1-5 1M T150 20um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/5 MnS PA-MeOH 1_5 1M/T150/MnS 1-5 1M T150 2.5um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/5 MnS PA-MeOH 1_5 1M/T300/6. MnS PA-MOH 1-5 1M 5um.tif
# /kaggle/working/MnS manuscript dataset/SEM/5 MnS PA-MeOH 1_5 1M/T300/6. MnS PA-MOH 1-5 1M 200um.tif
# /kaggle/working/MnS manuscript dataset/SEM/5 MnS PA-MeOH 1_5 1M/T300/6. MnS PA-MOH 1-5 1M 2.5um.tif
# /kaggle/working/MnS manuscript dataset/SEM/5 MnS PA-MeOH 1_5 1M/T300/6. MnS PA-MOH 1-5 1M 20um.tif
# /kaggle/working/MnS manuscript dataset/SEM/5 MnS PA-MeOH 1_5 1M/T60/MnS 1-5 1M T60 20um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/5 MnS PA-MeOH 1_5 1M/T60/MnS 1-5 1M T60 2.5um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/5 MnS PA-MeOH 1_5 1M/T60/MnS 1-5 1M T60 200um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/5 MnS PA-MeOH 1_5 1M/T60/MnS 1-5 1M T60 200um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/5 MnS PA-MeOH 1_5 1M/T60/MnS 1-5 1M T60 5um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/5 MnS PA-MeOH 1_5 1M/T60/MnS 1-5 1M T60 20um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/5 MnS PA-MeOH 1_5 1M/T60/MnS 1-5 1M T60 5um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/5 MnS PA-MeOH 1_5 1M/T60/MnS 1-5 1M T60 2.5um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/3 MnS PA-AN 1_1 1M/T150/MnS 1-1 1M T150 20um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/3 MnS PA-AN 1_1 1M/T150/MnS 1-1 1M T150 5um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/3 MnS PA-AN 1_1 1M/T150/MnS 1-1 1M T150 5um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/3 MnS PA-AN 1_1 1M/T150/MnS 1-1 1M T150 20um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/3 MnS PA-AN 1_1 1M/T150/MnS 1-1 1M T150 2.5um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/3 MnS PA-AN 1_1 1M/T150/MnS 1-1 1M T150 2.5um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/3 MnS PA-AN 1_1 1M/T300/8. MnS PA-AN 1-1 1M 2.5um.tif
# /kaggle/working/MnS manuscript dataset/SEM/3 MnS PA-AN 1_1 1M/T300/8. MnS PA-AN 1-1 1M 200um.tif
# /kaggle/working/MnS manuscript dataset/SEM/3 MnS PA-AN 1_1 1M/T300/8. MnS PA-AN 1-1 1M 5um.tif
# /kaggle/working/MnS manuscript dataset/SEM/3 MnS PA-AN 1_1 1M/T300/8. MnS PA-AN 1-1 1M 20um.tif
# /kaggle/working/MnS manuscript dataset/SEM/3 MnS PA-AN 1_1 1M/T60/MnS 1-1 1M T60 5um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/3 MnS PA-AN 1_1 1M/T60/MnS 1-1 1M T60 2.5um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/3 MnS PA-AN 1_1 1M/T60/MnS 1-1 1M T60 20um v2.tif
# /kaggle/working/MnS manuscript dataset/SEM/3 MnS PA-AN 1_1 1M/T60/MnS 1-1 1M T60 2.5um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/3 MnS PA-AN 1_1 1M/T60/MnS 1-1 1M T60 5um v1.tif
# /kaggle/working/MnS manuscript dataset/SEM/3 MnS PA-AN 1_1 1M/T60/MnS 1-1 1M T60 20um v1.tif
# /kaggle/working/MnS manuscript dataset/EDS/EDS.csv
# /kaggle/working/MnS manuscript dataset/EDS/MnS 1-2.5 1M dissolution time test.csv
# /kaggle/working/MnS manuscript dataset/photocatalysis kinetics meassurement/MnS_PA-AN_1_1_MB_photodegradation.csv
# /kaggle/working/MnS manuscript dataset/photocatalysis kinetics meassurement/MnS_PA1_5_MB_photodegradation.csv
# /kaggle/working/MnS manuscript dataset/photocatalysis kinetics meassurement/MnS_PA1_1_MB_photodegradation.csv
# /kaggle/working/MnS manuscript dataset/photocatalysis kinetics meassurement/pure_solution_MB_photodegradation.csv
# /kaggle/working/MnS manuscript dataset/photocatalysis kinetics meassurement/MnS_PA-AN_1_5_MB_photodegradation.csv
# /kaggle/working/MnS manuscript dataset/photocatalysis kinetics meassurement/MnS_PA-MeOH_1_1_MB_photodegradation.csv
# /kaggle/working/MnS manuscript dataset/photocatalysis kinetics meassurement/MnS_PA-MeOH_1_5_MB_photodegradation.csv
# /kaggle/working/MnS manuscript dataset/XRD/MnS -2-PA-05M-1-2,5-GIXRD omega05deg.xy
# /kaggle/working/MnS manuscript dataset/XRD/MnS -1-GIXRD omega05deg.xy
# /kaggle/working/MnS manuscript dataset/XRD/MnS -6-PA+AN-1M-1-1-GIXRD omega05deg.xy
# /kaggle/working/MnS manuscript dataset/XRD/MnS -4-PA+MeOH-1M-1-1-GIXRD omega05deg.xy
# /kaggle/working/MnS manuscript dataset/XRD/MnS -6-PA+AN-1M-1-1-GIXRD omega05deg-V2.xy
# /kaggle/working/MnS manuscript dataset/XRD/MnS -5-PA+MeOH-05M-1-2,5-GIXRD omega05deg.xy
# /kaggle/working/MnS manuscript dataset/XRD/MnS -3-PA-1M-1-5-GIXRD omega05deg.xy
# /kaggle/working/MnS manuscript dataset/FTIR/precipitates from solution/MnS 1_1 PA_MeOH.dpt
# /kaggle/working/MnS manuscript dataset/FTIR/precipitates from solution/MnS 1_1 PA_AN.dpt
# /kaggle/working/MnS manuscript dataset/FTIR/precipitates from solution/MnS 1_5 PA_AN.dpt
# /kaggle/working/MnS manuscript dataset/FTIR/precipitates from solution/MnS 1_5 PA_MeOH.dpt
# /kaggle/working/MnS manuscript dataset/FTIR/precipitates from solution/MnS 1_5 PA.dpt
# /kaggle/working/MnS manuscript dataset/FTIR/precipitates from solution/MnS 1_1 PA.dpt
# /kaggle/working/MnS manuscript dataset/FTIR/films/MnS_PA_1ku1_T300.0.dpt
# /kaggle/working/MnS manuscript dataset/FTIR/films/MnS_PA_1_5_T150.0.dpt
# /kaggle/working/MnS manuscript dataset/FTIR/films/MnS_PA_MeOH_1ku1_c1M_T60.0.dpt
# /kaggle/working/MnS manuscript dataset/FTIR/films/MnS_PA_MeOH_1_1_T300.0.dpt
# /kaggle/working/MnS manuscript dataset/FTIR/films/pure_sulfur PA_T60 V2.dpt
# /kaggle/working/MnS manuscript dataset/FTIR/films/MnS_PA_1ku1_c1M_T150.0.dpt
# /kaggle/working/MnS manuscript dataset/FTIR/films/MnS_PA_1ku1_c1M_T60.0.dpt
# /kaggle/working/MnS manuscript dataset/FTIR/films/MnS_PA_1_1_T300.0.dpt
# /kaggle/working/MnS manuscript dataset/FTIR/films/MnS_AN_1ku1_c1M_T60.0.dpt
# /kaggle/working/MnS manuscript dataset/FTIR/films/MnS_PA_MeOH_1_5_T300.1.dpt
# /kaggle/working/MnS manuscript dataset/FTIR/films/MnS_PA_1ku5_c1M_T60.0.dpt
# /kaggle/working/MnS manuscript dataset/FTIR/films/MnS_PA_AN_1ku1_T300.0.dpt
# /kaggle/working/MnS manuscript dataset/FTIR/films/MnS_PA_1ku5_T300.0.dpt
# /kaggle/working/MnS manuscript dataset/FTIR/films/MnS_PA_1ku5_T150.0.dpt
# /kaggle/working/MnS manuscript dataset/FTIR/films/pure sulfur PA_T60.0.dpt
# /kaggle/working/MnS manuscript dataset/FTIR/films/MnS_PA_MeOH_1ku5_T150.0.dpt
# /kaggle/working/MnS manuscript dataset/FTIR/films/MnS_PA_MeOH_1ku1_T300.0.dpt
# /kaggle/working/MnS manuscript dataset/FTIR/films/MnS_PA_1_5_T300.0.dpt
# /kaggle/working/MnS manuscript dataset/FTIR/films/MnS_PA_AN_1_1_T150.0.dpt
# /kaggle/working/MnS manuscript dataset/FTIR/films/MnS_PA_MeOH_1_1_T150.0.dpt
# /kaggle/working/MnS manuscript dataset/FTIR/films/MnS_PA_MeOH_1ku5_c1M_T60.0.dpt
# /kaggle/working/MnS manuscript dataset/FTIR/films/MnS_PA_MeOH_1_5_T150.0.dpt
# /kaggle/working/MnS manuscript dataset/FTIR/films/MnS_PA_1ku5_c1M_T150.0.dpt
# /kaggle/working/MnS manuscript dataset/FTIR/films/MnS_PA_AN_1_5_T300.0.dpt
# /kaggle/working/MnS manuscript dataset/FTIR/films/MnS_PA_AN_1ku5_T300.0.dpt
# /kaggle/working/MnS manuscript dataset/FTIR/films/MnS_AN_1ku5_c1M_T60.0.dpt
# /kaggle/working/MnS manuscript dataset/FTIR/films/MnS_PA_AN_1ku1_T150.0.dpt
# /kaggle/working/MnS manuscript dataset/FTIR/films/MnS_PA_MeOH_1ku1_T150.0.dpt
# /kaggle/working/MnS manuscript dataset/FTIR/films/MnS_PA_AN_1_1_T300.0.dpt
# /kaggle/working/MnS manuscript dataset/FTIR/films/MnS_PA_MeOH_1ku5_T300.1.dpt
# /kaggle/working/MnS manuscript dataset/FTIR/films/MnS_AN_1ku5_c1M_T150.0.dpt
# /kaggle/working/MnS manuscript dataset/AFM-scans/MnS PA AN 1ku1 0,5M T60 2,5X2,5_2.png
# /kaggle/working/MnS manuscript dataset/AFM-scans/MnS PA 1ku5 c1 T60 2,5x2,5_2.png
# /kaggle/working/MnS manuscript dataset/AFM-scans/MnS PA 1ku5 c1 T150 2,5x2,5.png
# /kaggle/working/MnS manuscript dataset/AFM-scans/MnS PAMetOH 1ku1 1M T60 2,5x2,5_2.png
# /kaggle/working/MnS manuscript dataset/AFM-scans/MnS PAMetOH 1ku5 1M T60 2,5x2,5_3.png
# /kaggle/working/MnS manuscript dataset/AFM-scans/MnS PA AN 1ku5 1M T150 2,5X2,5.png
# /kaggle/working/MnS manuscript dataset/AFM-scans/MnS PA AN 1ku1 1M T60 2,5X2,5_3.png
# /kaggle/working/MnS manuscript dataset/AFM-scans/MnS PA 1ku5 c0,1 T60 2,5x2,5.png
# /kaggle/working/MnS manuscript dataset/AFM-scans/MnS PAMetOH 1ku5 1M T60 2,5x2,5.png
# /kaggle/working/MnS manuscript dataset/AFM-scans/MnS PAMetOH 1ku5 0,1M T60 2,5x2,5.png
# /kaggle/working/MnS manuscript dataset/AFM-scans/MnS PA 1ku5 c0,1 T60 2,5x2,5_2.png
# /kaggle/working/MnS manuscript dataset/AFM-scans/MnS PA 1ku1 c0,1 T150 2,5x2,5.png
# /kaggle/working/MnS manuscript dataset/AFM-scans/MnS PA AN 1ku5 1M T60 2,5X2,5.png
# /kaggle/working/MnS manuscript dataset/AFM-scans/MnS PA 1ku1 c0,1 T60 2,5x2,5.png
# /kaggle/working/MnS manuscript dataset/AFM-scans/MnS PA AN 1ku5 1M T60 2,5X2,5_2.png
# /kaggle/working/MnS manuscript dataset/AFM-scans/MnS PAMetOH 1ku5 1M T60 2,5x2,5 FAZE.png
# /kaggle/working/MnS manuscript dataset/AFM-scans/MnS PA AN 1ku1 0,5M T60 2,5X2,5_3.png
# /kaggle/working/MnS manuscript dataset/AFM-scans/MnS PA 1ku1 c1 T150 2,5x2,5.png
# /kaggle/working/MnS manuscript dataset/AFM-scans/MnS PA 1ku5 c1 T60 2,5x2,5 FAZE.png
# /kaggle/working/MnS manuscript dataset/AFM-scans/MnS PAMetOH 1ku1 0,5M T150 2,5x2,5.png
# /kaggle/working/MnS manuscript dataset/AFM-scans/MnS PA AN 1ku1 1M T150 2,5X2,5 FAZE.png
# /kaggle/working/MnS manuscript dataset/AFM-scans/MnS PA AN 1ku1 0,5M T60 2,5X2,5_5.png
# /kaggle/working/MnS manuscript dataset/AFM-scans/MnS PA 1ku1 c1 T60 b�l� skvrna 2,5x2,5.png
# /kaggle/working/MnS manuscript dataset/AFM-scans/MnS PAMetOH 1ku1 0,5M T60 2,5x2,5_2.png
# /kaggle/working/MnS manuscript dataset/AFM-scans/MnS PA AN 1ku1 1M T150 2,5X2,5_3.png
# /kaggle/working/MnS manuscript dataset/AFM-scans/MnS PA 1ku1 c1 T60 2,5x2,5.png
# /kaggle/working/MnS manuscript dataset/AFM-scans/MnS PA AN 1ku1 1M T60 2,5X2,5_2.png
# /kaggle/working/MnS manuscript dataset/AFM-scans/MnS PAMetOH 1ku1 0,5M T60 2,5x2,5.png
# /kaggle/working/MnS manuscript dataset/AFM-scans/MnS PA AN 1ku1 1M T150 2,5X2,5_2.png
# /kaggle/working/MnS manuscript dataset/AFM-scans/MnS PAMetOH 1ku1 1M T150 2,5x2,5_2.png
# /kaggle/working/MnS manuscript dataset/AFM-scans/MnS PA AN 1ku1 0,5M T60 2,5X2,5_4.png
# /kaggle/working/MnS manuscript dataset/AFM-scans/MnS PA 1ku5 c1 T60 2,5x2,5.png
# /kaggle/working/MnS manuscript dataset/AFM-scans/MnS PA AN 1ku1 1M T150 2,5X2,5.png
# /kaggle/working/MnS manuscript dataset/AFM-scans/MnS PA AN 1ku1 1M T150 2,5X2,5_4.png
# /kaggle/working/MnS manuscript dataset/AFM-scans/MnS PA 1ku1 c0,1 T60 2,5x2,5_2.png
# /kaggle/working/MnS manuscript dataset/AFM-scans/MnS PA 1